# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauravb853/Mini_sales_analysis-/blob/main/Uber_Data_Analysis_Complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import calendar

# %%
Data= pd.read_csv('/content/drive/MyDrive/Raw_UberDataset.csv')
Data.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
Data.isnull().any()
# Out:
# START_DATE    False
# END_DATE       True
# CATEGORY       True
# START          True
# STOP           True
# MILES         False
# PURPOSE        True
# dtype: bool

# %%
Data.isnull().sum()
# Out:
# START_DATE      0
# END_DATE        1
# CATEGORY        1
# START           1
# STOP            1
# MILES           0
# PURPOSE       503
# dtype: int64

# %%
Data = Data.dropna()

# %%
Data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY            START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#               STOP  MILES          PURPOSE  DAY  MONTH  YEAR  DAYOFWEEK  \
# 0      Fort Pierce    5.1   Meal/Entertain    1      1  2016          4
# 2      Fort Pierce    4.8  Errand/Supplies    2      1  2016          5
# 3      Fort Pierce    4.7          Meeting    5      1  2016          1
# 4  West Palm Beach   63.7   Customer Visit    6      1  2016          2
# 5  West Palm Beach    4.3   Meal/Entertain    6      1  2016          2
#
#      WEEKDAY
# 0     Friday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday
# 5  Wednesday

# %%
Data.dtypes
# Out:
# START_DATE    datetime64[ns]
# END_DATE      datetime64[ns]
# CATEGORY              object
# START                 object
# STOP                  object
# MILES                float64
# PURPOSE               object
# DAY                    Int64
# MONTH                  Int64
# YEAR                   Int64
# DAYOFWEEK              Int64
# WEEKDAY               object
# dtype: object

# %%
Data.dtypes
# Out:
# START_DATE    datetime64[ns]
# END_DATE      datetime64[ns]
# CATEGORY              object
# START                 object
# STOP                  object
# MILES                float64
# PURPOSE               object
# DAY                    Int64
# MONTH                  Int64
# YEAR                   Int64
# DAYOFWEEK              Int64
# WEEKDAY               object
# dtype: object

# %%
Data['START_DATE']= pd.to_datetime(Data['START_DATE'])
Data['DAY'] = Data['START_DATE'].dt.day.astype('Int64')
Data['MONTH'] = Data['START_DATE'].dt.month.astype('Int64')
Data['YEAR'] = Data['START_DATE'].dt.year.astype('Int64')
Data['DAYOFWEEK'] = Data['START_DATE'].dt.dayofweek.astype('Int64')
Data['WEEKDAY'] = Data['START_DATE'].dt.day_name()

# %%
Data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY            START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#               STOP  MILES          PURPOSE  DAY  MONTH  YEAR  DAYOFWEEK  \
# 0      Fort Pierce    5.1   Meal/Entertain    1      1  2016          4
# 2      Fort Pierce    4.8  Errand/Supplies    2      1  2016          5
# 3      Fort Pierce    4.7          Meeting    5      1  2016          1
# 4  West Palm Beach   63.7   Customer Visit    6      1  2016          2
# 5  West Palm Beach    4.3   Meal/Entertain    6      1  2016          2
#
#      WEEKDAY
# 0     Friday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday
# 5  Wednesday

# %% [markdown]
# ## To count anything

# %%
Data['CATEGORY'].value_counts()
# Out:
# CATEGORY
# Business    647
# Personal      6
# Name: count, dtype: int64

# %% [markdown]
# # To Visualize the data

# %%
sns.countplot(x='CATEGORY',data=Data)
# Out:
# <Axes: xlabel='CATEGORY', ylabel='count'>

# %%
Data['MILES'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Checking the peek Hours Using Plt lib

# %%
Data['START_DATE'].dt.hour.value_counts().plot(kind='bar',color='orange',figsize=(12,6))
plt.xlabel('Hours')
plt.ylabel('Frequency')
plt.title('Rides per Hour')
# Out:
# Text(0.5, 1.0, 'Rides per Hour')

# %% [markdown]
# # Check the purpose of trip

# %%
Data['PURPOSE'].value_counts().plot(kind='bar',color='blue',figsize=(12,6))
plt.xlabel('Purpose')
plt.ylabel('Frequency')
plt.title('Most popular Rides among purpose')
# Out:
# Text(0.5, 1.0, 'Most popular Rides among purpose')

# %%
Data['WEEKDAY'].value_counts().plot(kind='bar',color='pink',figsize=(11,5.5))
plt.xlabel('Day Name')
plt.ylabel('Number of Rides')
plt.title('Most rides on single Weekday')
# Out:
# Text(0.5, 1.0, 'Most rides on single Weekday')

# %%
Data['MONTH'].value_counts().plot(kind='bar',color='green',figsize=(11,6))
plt.xlabel('Month')
plt.ylabel('Number of Rides')
plt.title('Most rides on single Month')
# Out:
# Text(0.5, 1.0, 'Most rides on single Month')

# %%
Data['START'].value_counts().plot(kind='bar',color='red',figsize=(25,10))
plt.xlabel('Start Point Name')
plt.ylabel('Number of Rides')
plt.title('Most Famouse Start point')
# Out:
# Text(0.5, 1.0, 'Most Famouse Start point')

# %%
Data['DAY'].value_counts().plot(kind='bar',color='Gold',figsize=(10,
                                                                5))
plt.show()
